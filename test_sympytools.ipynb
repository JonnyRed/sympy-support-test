# %%
import sys

# Importing utility functions from the sympy_support package
import sympy_support.spv_utils as ssu
import sympy_support.chainrule as ssc
import sympy_support.generalised_chain_rule as ssg

# Importing the columnize function from IPython for better display of lists
from IPython.utils.text import columnize


def test():
    """
    The main function of the module. It prints out the system path,
    the directory of sympy_support utility functions, and runs doctests
    on the `sympy_support.utils` module.
    """
    import doctest

    # Display the system path in a columnized format
    print(columnize(sys.path))

    # Display the directory of sympy_support utility functions in a
    # columnized format
    print(columnize(dir(ssu)))
    print(columnize(dir(ssc)))
    print(columnize(dir(ssg)))

    # Run doctests on the sympy_support.utils module with verbose output

    verbose = True
    doctest.testmod(ssu, verbose=verbose)
    doctest.testmod(ssc, verbose=verbose)
    doctest.testmod(ssg, verbose=verbose)


# Ensures the main function is called only when the script is executed directly
test()
# Out:
# d:\Users\John\Documents\IPython Notebooks\sympy\sympy-support-test
# D:\Users\John\Documents\IPython Notebooks\sympy\sympy-notes
# d:\Users\John\miniconda3\envs\sympy\python310.zip
# d:\Users\John\miniconda3\envs\sympy\DLLs
# d:\Users\John\miniconda3\envs\sympy\lib
# d:\Users\John\miniconda3\envs\sympy
#
# C:\Users\John\AppData\Roaming\Python\Python310\site-packages
# d:\Users\John\miniconda3\envs\sympy\lib\site-packages
# d:\Users\John\miniconda3\envs\sympy\lib\site-packages\win32
# d:\Users\John\miniconda3\envs\sympy\lib\site-packages\win32\lib
# d:\Users\John\miniconda3\envs\sympy\lib\site-packages\Pythonwin
#
# E                 __cached__   angle_between_vectors          spv
# HALF              __doc__      create_3d_components           vector
# NEGATIVEINFINITY  __file__     create_vectors                 vector_cos
# ONE               __loader__   ipd                            vector_line
# PI                __name__     print_aligned_latex_equations  vector_line_eqn
# POSITIVEINFINITY  __package__  reference_frame                vector_to_list
# __builtins__      __spec__     sp
#
# E                 __doc__      chain_rule_derivative
# HALF              __file__     find_dependent_variable_differentials
# PI                __loader__   generalised_chain_rule
# POSITIVEINFINITY  __name__     generalised_chain_rule_for
# __builtins__      __package__  sp
# __cached__        __spec__
#
# E                 __doc__      chain_rule_derivative
# HALF              __file__     doctest
# PI                __loader__   find_dependent_variable_differentials
# POSITIVEINFINITY  __name__     generalised_chain_rule
# __builtins__      __package__  generalised_chain_rule_for
# __cached__        __spec__     sp
#
# Trying:
#     A = spv.ReferenceFrame('A')
# Expecting nothing
# ok
# Trying:
#     a = 3 * A.x + 4 * A.y
# Expecting nothing
# ok
# Trying:
#     b = 2 * A.x - A.y
# Expecting nothing
# ok
# Trying:
#     angle_between_vectors(a, b)
# Expecting:
#     acos(2*sqrt(5)/25)
# ok
# Trying:
#     v1 = A.x
# Expecting nothing
# ok
# Trying:
#     v2 = A.y
# Expecting nothing
# ok
# Trying:
#     v1.angle_between(v2)
# Expecting:
#     pi/2
# ok
# Trying:
#     v3 = A.x + A.y + A.z
# Expecting nothing
# ok
# Trying:
#     v1.angle_between(v3)
# Expecting:
#     acos(sqrt(3)/3)
# ok
# Trying:
#     create_3d_components('a')
# Expecting:
#     [(a_{x}, a_{y}, a_{z})]
# ok
# Trying:
#     create_3d_components('a', 'b')
# Expecting:
#     [(a_{x}, a_{y}, a_{z}), (b_{x}, b_{y}, b_{z})]
# ok
# Trying:
#     N = spv.ReferenceFrame('N')
# Expecting nothing
# ok
# Trying:
#     create_vectors(N, "a")
# Expecting:
#     [a_{x}*N.x + a_{y}*N.y + a_{z}*N.z]
# ok
# Trying:
#     create_vectors(N, "a", "b")
# Expecting:
#     [a_{x}*N.x + a_{y}*N.y + a_{z}*N.z, b_{x}*N.x + b_{y}*N.y + b_{z}*N.z]
# ok
# Trying:
#     F = reference_frame("F")
# Expecting nothing
# ok
# Trying:
#     F
# Expecting:
#     F
# ok
# Trying:
#     F.x
# Expecting:
#     F.x
# ok
# Trying:
#     F.y
# Expecting:
#     F.y
# ok
# Trying:
#     F.z
# Expecting:
#     F.z
# ok
# Trying:
#     N = spv.ReferenceFrame('N')
# Expecting nothing
# ok
# Trying:
#     vector(N, 1, 0, 0)
# Expecting:
#     N.x
# ok
# Trying:
#     vector(N, 0, 1, 0)
# Expecting:
#     N.y
# ok
# Trying:
#     vector(N, 0, 0, 1)
# Expecting:
#     N.z
# ok
# Trying:
#     vector(N, 1, 2)
# Expecting:
#     N.x + 2*N.y
# ok
# Trying:
#     vector(N, 1, 2, 3)
# Expecting:
#     N.x + 2*N.y + 3*N.z
# ok
# Trying:
#     vector(N, 5.0, 5.1, 7.7)
# Expecting:
#     5.0*N.x + 5.1*N.y + 7.7*N.z
# ok
# Trying:
#     vector(N, 1, 2, 3)
# Expecting:
#     N.x + 2*N.y + 3*N.z
# ok
# Trying:
#     N = spv.ReferenceFrame('N')
# Expecting nothing
# ok
# Trying:
#     vector_cos(N, 1, PI/2, 0)
# Expecting:
#     N.y
# ok
# Trying:
#     vector_cos(N, 1, 0, PI/2)
# Expecting:
#     N.x
# ok
# Trying:
#     vector_cos(N, sp.sqrt(2), PI/4, PI/4)
# Expecting:
#     N.x + N.y
# ok
# Trying:
#     vector_cos(N, 1, PI/2, 0)
# Expecting:
#     N.y
# ok
# Trying:
#     vector_cos(N, 41, PI/2 + PI/4, 2*PI/3, PI/3)
# Expecting:
#     - 41*sqrt(2)/2*N.x - 41/2*N.y + 41/2*N.z
# ok
# Trying:
#     n = sp.sqrt(93)
# Expecting nothing
# ok
# Trying:
#     vector_cos(N, n, 5/n, 2/n, 8/n)
# Expecting:
#     sqrt(93)*cos(5*sqrt(93)/93)*N.x + sqrt(93)*cos(2*sqrt(93)/93)*N.y + sqrt(93)*cos(8*sqrt(93)/93)*N.z
# ok
# Trying:
#     A = spv.ReferenceFrame('A')
# Expecting nothing
# ok
# Trying:
#     start = A.x*0 + A.y*0 + A.z*0  # Zero vector
# Expecting nothing
# ok
# Trying:
#     finish = 3 * A.x + 4 * A.y + 5 * A.z
# Expecting nothing
# ok
# Trying:
#     lamda = sp.symbols('lambda')
# Expecting nothing
# ok
# Trying:
#     vector_line_eqn(start, finish, lamda)
# Expecting:
#     3*lambda*A.x + 4*lambda*A.y + 5*lambda*A.z
# ok
# Trying:
#     start = 2 * A.x - A.y
# Expecting nothing
# ok
# Trying:
#     finish = 4 *A.y + 3 * A.z
# Expecting nothing
# ok
# Trying:
#     vector_line_eqn(start, finish, lamda)
# Expecting:
#     (2 - 2*lambda)*A.x + (5*lambda - 1)*A.y + 3*lambda*A.z
# ok
# Trying:
#     N = spv.ReferenceFrame('N')
# Expecting nothing
# ok
# Trying:
#     v = 3 * N.x + 4 * N.y + 5 * N.z
# Expecting nothing
# ok
# Trying:
#     vector_to_list(N, v)
# Expecting:
#     [3, 4, 5]
# ok
# Trying:
#     v = 3 * N.x + 4 * N.y
# Expecting nothing
# ok
# Trying:
#     vector_to_list(N, v)
# Expecting:
#     [3, 4, 0]
# ok
# 3 items had no tests:
#     sympy_support.spv_utils
#     sympy_support.spv_utils.print_aligned_latex_equations
#     sympy_support.spv_utils.vector_line
# 8 items passed all tests:
#    9 tests in sympy_support.spv_utils.angle_between_vectors
#    2 tests in sympy_support.spv_utils.create_3d_components
#    3 tests in sympy_support.spv_utils.create_vectors
#    5 tests in sympy_support.spv_utils.reference_frame
#    8 tests in sympy_support.spv_utils.vector
#    8 tests in sympy_support.spv_utils.vector_cos
#    8 tests in sympy_support.spv_utils.vector_line_eqn
#    5 tests in sympy_support.spv_utils.vector_to_list
# 48 tests in 11 items.
# 48 passed and 0 failed.
# Test passed.
# Trying:
#     x, y, z, u, v = sp.symbols("x, y, z, u, v", real=True)
# Expecting nothing
# ok
# Trying:
#     w = 3 * x**2 - 2 * x * y + 4 * z**2
# Expecting nothing
# ok
# Trying:
#     dependents = {x: sp.exp(u) * sp.sin(v), y: sp.exp(u) * sp.cos(v), z: sp.exp(u)}
# Expecting nothing
# ok
# Trying:
#     result = chain_rule_derivative(w, dependents, u, v)
# Expecting nothing
# ok
# Trying:
#     result[0].lhs
# Expecting:
#     Derivative(f(u, v), u)
# ok
# Trying:
#     result[0].rhs
# Expecting:
#     2*(3*sin(v)**2 - sin(2*v) + 4)*exp(2*u)
# ok
# Trying:
#     result[0]
# Expecting:
#     Eq(Derivative(f(u, v), u), 2*(3*sin(v)**2 - sin(2*v) + 4)*exp(2*u))
# ok
# Trying:
#     result[1].lhs
# Expecting:
#     Derivative(f(u, v), v)
# ok
# Trying:
#     result[1].rhs
# Expecting:
#     (3*sin(2*v) - 2*cos(2*v))*exp(2*u)
# ok
# Trying:
#     result[1]
# Expecting:
#     Eq(Derivative(f(u, v), v), (3*sin(2*v) - 2*cos(2*v))*exp(2*u))
# ok
# Trying:
#     x, y, r, theta = sp.symbols("x, y, r, theta", real=True)
# Expecting nothing
# ok
# Trying:
#     dependents = {x: r * sp.cos(theta), y: r * sp.sin(theta)}
# Expecting nothing
# ok
# Trying:
#     f = sp.Function("f")
# Expecting nothing
# ok
# Trying:
#     result = find_dependent_variable_differentials(f, dependents, r, theta)
# Expecting nothing
# ok
# Trying:
#     result[sp.Derivative(f(x, y), x)]
# Expecting:
#     cos(theta)*Derivative(f(r, theta), r) - sin(theta)*Derivative(f(r, theta), theta)/r
# ok
# Trying:
#     result[sp.Derivative(f(x, y), y)]
# Expecting:
#     sin(theta)*Derivative(f(r, theta), r) + cos(theta)*Derivative(f(r, theta), theta)/r
# ok
# Trying:
#     x, y, t = sp.symbols("x, y, t", real=True)
# Expecting nothing
# ok
# Trying:
#     dependents = {x: sp.sin(t), y: sp.cos(t)}
# Expecting nothing
# ok
# Trying:
#     f = sp.Function("f")
# Expecting nothing
# ok
# Trying:
#     generalised_chain_rule(f, dependents, t)
# Expecting:
#     (Eq(Derivative(f(t), t), -sin(t)*Derivative(f(x, y), y) + cos(t)*Derivative(f(x, y), x)),)
# ok
# Trying:
#     generalised_chain_rule(f, dependents, t)[0].lhs
# Expecting:
#     Derivative(f(t), t)
# ok
# Trying:
#     generalised_chain_rule(f, dependents, t)[0].rhs
# Expecting:
#     -sin(t)*Derivative(f(x, y), y) + cos(t)*Derivative(f(x, y), x)
# ok
# Trying:
#     x, y, z, r, theta = sp.symbols("x, y, z, r, theta", real=True)
# Expecting nothing
# ok
# Trying:
#     f = sp.symbols("f", cls=sp.Function)
# Expecting nothing
# ok
# Trying:
#     generalised_chain_rule_for(0, f, {x: r * sp.cos(theta), y: r * sp.sin(theta)}, r, theta)
# Expecting:
#     sin(theta)*Derivative(f(x, y), y) + cos(theta)*Derivative(f(x, y), x)
# ok
# Trying:
#     generalised_chain_rule_for(1, f, {x: r * sp.cos(theta), y: r * sp.sin(theta)}, r, theta)
# Expecting:
#     -r*sin(theta)*Derivative(f(x, y), x) + r*cos(theta)*Derivative(f(x, y), y)
# ok
# 1 items had no tests:
#     sympy_support.chainrule
# 4 items passed all tests:
#   10 tests in sympy_support.chainrule.chain_rule_derivative
#    6 tests in sympy_support.chainrule.find_dependent_variable_differentials
#    6 tests in sympy_support.chainrule.generalised_chain_rule
#    4 tests in sympy_support.chainrule.generalised_chain_rule_for
# 26 tests in 5 items.
# 26 passed and 0 failed.
# Test passed.
# Trying:
#     x, y, z, u, v = sp.symbols("x, y, z, u, v", real=True)
# Expecting nothing
# ok
# Trying:
#     w = 3 * x**2 - 2 * x * y + 4 * z**2
# Expecting nothing
# ok
# Trying:
#     dependents = {x: sp.exp(u) * sp.sin(v), y: sp.exp(u) * sp.cos(v), z: sp.exp(u)}
# Expecting nothing
# ok
# Trying:
#     result = chain_rule_derivative(w, dependents, u, v)
# Expecting nothing
# ok
# Trying:
#     result[0].lhs
# Expecting:
#     Derivative(f(u, v), u)
# ok
# Trying:
#     result[0].rhs
# Expecting:
#     2*(3*sin(v)**2 - sin(2*v) + 4)*exp(2*u)
# ok
# Trying:
#     result[0]
# Expecting:
#     Eq(Derivative(f(u, v), u), 2*(3*sin(v)**2 - sin(2*v) + 4)*exp(2*u))
# ok
# Trying:
#     result[1].lhs
# Expecting:
#     Derivative(f(u, v), v)
# ok
# Trying:
#     result[1].rhs
# Expecting:
#     (3*sin(2*v) - 2*cos(2*v))*exp(2*u)
# ok
# Trying:
#     result[1]
# Expecting:
#     Eq(Derivative(f(u, v), v), (3*sin(2*v) - 2*cos(2*v))*exp(2*u))
# ok
# Trying:
#     x, y, r, theta = sp.symbols("x, y, r, theta", real=True)
# Expecting nothing
# ok
# Trying:
#     dependents = {x: r * sp.cos(theta), y: r * sp.sin(theta)}
# Expecting nothing
# ok
# Trying:
#     f = sp.Function("f")
# Expecting nothing
# ok
# Trying:
#     result = find_dependent_variable_differentials(f, dependents, r, theta)
# Expecting nothing
# ok
# Trying:
#     result[sp.Derivative(f(x, y), x)]
# Expecting:
#     cos(theta)*Derivative(f(r, theta), r) - sin(theta)*Derivative(f(r, theta), theta)/r
# ok
# Trying:
#     result[sp.Derivative(f(x, y), y)]
# Expecting:
#     sin(theta)*Derivative(f(r, theta), r) + cos(theta)*Derivative(f(r, theta), theta)/r
# ok
# Trying:
#     x, y, t = sp.symbols("x, y, t", real=True)
# Expecting nothing
# ok
# Trying:
#     dependents = {x: sp.sin(t), y: sp.cos(t)}
# Expecting nothing
# ok
# Trying:
#     f = sp.Function("f")
# Expecting nothing
# ok
# Trying:
#     generalised_chain_rule(f, dependents, t)
# Expecting:
#     (Eq(Derivative(f(t), t), -sin(t)*Derivative(f(x, y), y) + cos(t)*Derivative(f(x, y), x)),)
# ok
# Trying:
#     generalised_chain_rule(f, dependents, t)[0].lhs
# Expecting:
#     Derivative(f(t), t)
# ok
# Trying:
#     generalised_chain_rule(f, dependents, t)[0].rhs
# Expecting:
#     -sin(t)*Derivative(f(x, y), y) + cos(t)*Derivative(f(x, y), x)
# ok
# Trying:
#     x, y, z, r, theta = sp.symbols("x, y, z, r, theta", real=True)
# Expecting nothing
# ok
# Trying:
#     f = sp.symbols("f", cls=sp.Function)
# Expecting nothing
# ok
# Trying:
#     generalised_chain_rule_for(0, f, {x: r * sp.cos(theta), y: r * sp.sin(theta)}, r, theta)
# Expecting:
#     sin(theta)*Derivative(f(x, y), y) + cos(theta)*Derivative(f(x, y), x)
# ok
# Trying:
#     generalised_chain_rule_for(1, f, {x: r * sp.cos(theta), y: r * sp.sin(theta)}, r, theta)
# Expecting:
#     -r*sin(theta)*Derivative(f(x, y), x) + r*cos(theta)*Derivative(f(x, y), y)
# ok
# 1 items had no tests:
#     sympy_support.generalised_chain_rule
# 4 items passed all tests:
#   10 tests in sympy_support.generalised_chain_rule.chain_rule_derivative
#    6 tests in sympy_support.generalised_chain_rule.find_dependent_variable_differentials
#    6 tests in sympy_support.generalised_chain_rule.generalised_chain_rule
#    4 tests in sympy_support.generalised_chain_rule.generalised_chain_rule_for
# 26 tests in 5 items.
# 26 passed and 0 failed.
# Test passed.
